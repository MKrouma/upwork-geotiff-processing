# %% [markdown]
# # Mchakato
# Mchakato, is a geodata processing to have elevation data.

# %%
# import
import os
import pandas as pd
import xarray as xr
import rioxarray
from rasterstats import zonal_stats, point_query
# import geopandas as gpd

# %%
# fecth elevation geotiff
elevation_geotiff = "../data/raw/Copernicus_DSM_30_N29_00_E014_00_DEM.tif"
elevation_raster = rioxarray.open_rasterio(elevation_geotiff)

display(elevation_raster)
# Out:
# <xarray.DataArray (band: 1, y: 1201, x: 1201)>
# [1442401 values with dtype=float32]
# Coordinates:
#   * band         (band) int32 1
#   * x            (x) float64 14.0 14.0 14.0 14.0 14.0 ... 15.0 15.0 15.0 15.0
#   * y            (y) float64 30.0 30.0 30.0 30.0 30.0 ... 29.0 29.0 29.0 29.0
#     spatial_ref  int32 0
# Attributes:
#     AREA_OR_POINT:  Point
#     scale_factor:   1.0
#     add_offset:     0.0

# %%
# rasterstats points queries
point_calcul_file = "../data/raw/points_to_calculate.geojson"
pts = point_query(point_calcul_file, elevation_geotiff)
# Out:
# c:\Users\Mamadou\Desktop\upwork-geotiff-processing\.env\lib\site-packages\rasterstats\io.py:328: NodataWarning: Setting nodata to -999; specify nodata explicitly
#   warnings.warn(

# %%
pts
# Out:
# [391.84177822548725, 443.66090104761923]
